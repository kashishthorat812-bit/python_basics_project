# %% [markdown]
# <a href="https://colab.research.google.com/github/kashishthorat812-bit/python_basics_project/blob/main/Q4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:
    def __init__(self, name, roll_no):
        self.name = name
        self.roll_no = roll_no
        self.marks_list = []

    def add_mark(self, mark):
        try:
            if 0 <= mark <= 100:
                self.marks_list.append(mark)
            else:
                print("Invalid mark!")
        except:
            print("Error!")

    def get_average(self):
        if self.marks_list:
            return sum(self.marks_list)/len(self.marks_list)
        return 0

    def display_info(self):
        print("\nName =", self.name)
        print("Roll No =", self.roll_no)
        print("Marks =", self.marks_list)
        print("Average =", self.get_average())

name = input("Enter Name: ")
roll = input("Enter Roll No: ")

s = Student(name, roll)

for i in range(5):
    mark = float(input(f"Enter mark {i+1} ="))
    s.add_mark(mark)

s.display_info()
