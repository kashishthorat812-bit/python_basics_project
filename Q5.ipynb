# %% [markdown]
# <a href="https://colab.research.google.com/github/kashishthorat812-bit/python_basics_project/blob/main/Q5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def student_database():
    students = {}

    while True:
        print("\n1.Add Student")
        print("2.Search Student")
        print("3.Display All")
        print("4.Exit")

        choice = input("\nEnter choice: ")

        if choice == "1":
            roll = input("Roll No = ")
            name = input("Name = ")
            age = input("Age = ")
            city = input("City = ")

            students.update({roll: {"name": name, "age": age, "city": city}})

        elif choice == "2":
            roll = input("Enter Roll No = ")
            print(students.get(roll, "Student Not Found"))

        elif choice == "3":
            for roll, data in students.items():
                print(roll, data)

        elif choice == "4":
            print("Exited")
            break

        else:
            print("Invalid Choice")

student_database()
