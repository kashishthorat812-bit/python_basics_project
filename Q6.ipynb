# %% [markdown]
# <a href="https://colab.research.google.com/github/kashishthorat812-bit/python_basics_project/blob/main/Q6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

try:
    numbers = set()

    while len(numbers) < 10:
        num = int(input("Enter a number: "))
        numbers.add(num)

    num_tuple = tuple(numbers)

    print("\nTuple:", num_tuple)

    print("3 Random Numbers:", random.sample(num_tuple, 3))

    total = sum(num_tuple)
    print("Square Root of Sum:", math.sqrt(total))

except ValueError:
    print("Invalid input!")
except Exception as e:
    print("Error:", e)
